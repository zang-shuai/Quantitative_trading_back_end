# %%
import rqdatac

rqdatac.init(username='17344455203', password='0105022601201,zS')

# %%
rqdatac.user.get_quota()
# Out:
# ---------------------------------------------------------------------------
# PermissionDenied                          Traceback (most recent call last)
# Input In [6], in <module>
# ----> 1 rqdatac.user.get_quota()
#
# File ~/miniforge3/envs/ai/lib/python3.9/site-packages/rqdatac/services/basic.py:836, in get_quota()
#     826 @export_as_api(namespace="user")
#     827 def get_quota():
#     828     """
#     829     获取用户配额信息
#     830     :return dict
#    (...)
#     834         license_type：账户类型(FULL: 付费类型，TRIAL: 试用类型， EDU: 教育网类型, OTHER: 其他类型)
#     835     """
# --> 836     data = get_client().execute("user.get_quota")
#     837     if data['bytes_limit'] > 0 and data["bytes_used"] >= data["bytes_limit"]:
#     838         warnings.warn("Traffic usage has been exceeded quota,"
#     839                       "Please call us at 0755-22676337 to upgrade"
#     840                       "your contract.")
#
# ...

# %%
import rqdatac, pandas, datetime

rqdatac.init(username='17344455203', password='0105022601201,zS')

rqdatac.get_price('000001.XSHE', start_date=20150101, end_date="2015-02-01")

rqdatac.get_price('000002.XSHE', start_date=pandas.Timestamp("20150101"), end_date=datetime.datetime(2015, 2, 1))
# Out:
# ---------------------------------------------------------------------------
# PermissionDenied                          Traceback (most recent call last)
# Input In [8], in <module>
#       1 import rqdatac, pandas, datetime
#       3 rqdatac.init(username='17344455203', password='0105022601201,zS')
# ----> 5 rqdatac.get_price('000001.XSHE', start_date=20150101, end_date="2015-02-01")
#       7 rqdatac.get_price('000002.XSHE', start_date=pandas.Timestamp("20150101"), end_date=datetime.datetime(2015, 2, 1))
#
# File ~/miniforge3/envs/ai/lib/python3.9/site-packages/rqdatac/decorators.py:150, in compatible_with_parm.<locals>.wrap(*args, **kwargs)
#     148         if item != value:
#     149             raise ValueError("'{}': except '{}', got '{}'".format(name, value, item))
# --> 150 return func(*args, **kwargs)
#
# ...

# %%
import tushare as ts

pro = ts.pro_api()
pro.query('daily', ts_code='000537.SZ')
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change  \
# 0     000537.SZ   20220407  16.66  16.66  15.42  15.70      16.47   -0.77
# 1     000537.SZ   20220406  16.97  16.97  16.32  16.47      16.98   -0.51
# 2     000537.SZ   20220401  16.80  17.17  16.32  16.98      17.01   -0.03
# 3     000537.SZ   20220331  17.51  17.63  16.70  17.01      17.63   -0.62
# 4     000537.SZ   20220330  16.90  17.82  16.85  17.63      16.81    0.82
# ...         ...        ...    ...    ...    ...    ...        ...     ...
# 4995  000537.SZ   20000907  32.39  33.35  32.33  32.74      32.38    0.36
# 4996  000537.SZ   20000906  33.16  33.17  32.20  32.38      33.17   -0.79
# 4997  000537.SZ   20000905  33.33  33.95  32.84  33.17      33.33   -0.16
# 4998  000537.SZ   20000904  33.21  33.90  32.64  33.33      33.23    0.10
# 4999  000537.SZ   20000831  34.00  34.00  32.98  33.23      34.27   -1.04
#
#       pct_chg        vol       amount
# 0     -4.6752  223540.15  351931.7800
# ...

# %%
pro = ts.pro_api()

fields = ['trade_date', 'open', 'high', 'low', 'close', 'pre_close', 'change', 'pct_chg', 'vol', 'amount']
fields = ','.join(fields)
df = pro.daily(ts_code='000001.SZ', start_date='20180701', end_date='20180718',fields=fields)
df
# Out:
#    trade_date  open  high   low  close  pre_close  change  pct_chg  \
# 0    20180718  8.75  8.85  8.69   8.70       8.72   -0.02    -0.23
# 1    20180717  8.74  8.75  8.66   8.72       8.73   -0.01    -0.11
# 2    20180716  8.85  8.90  8.69   8.73       8.88   -0.15    -1.69
# 3    20180713  8.92  8.94  8.82   8.88       8.88    0.00     0.00
# 4    20180712  8.60  8.97  8.58   8.88       8.64    0.24     2.78
# 5    20180711  8.76  8.83  8.68   8.78       8.98   -0.20    -2.23
# 6    20180710  9.02  9.02  8.89   8.98       9.03   -0.05    -0.55
# 7    20180709  8.69  9.03  8.68   9.03       8.66    0.37     4.27
# 8    20180706  8.61  8.78  8.45   8.66       8.60    0.06     0.70
# 9    20180705  8.62  8.73  8.55   8.60       8.61   -0.01    -0.12
# 10   20180704  8.63  8.75  8.61   8.61       8.67   -0.06    -0.69
# 11   20180703  8.69  8.70  8.45   8.67       8.61    0.06     0.70
# 12   20180702  9.05  9.05  8.55   8.61       9.09   -0.48    -5.28
#
# ...
